# %% [markdown]
# # 1. Recap first part at 2pm - Numpy Reshaping

# %%
import numpy as np
a1 = np.arange(24)
a1

# %%
a1.shape

# %%
a1.ndim

# %%
a1[0]

# %%
a1.reshape(1,24)

# %%
a1.reshape(1,24)[0,3]

# %%
a1

# %%
a1.reshape(24,1)

# %%
a1 = a1.reshape(24,1)

# %%
a1.reshape(24,1).reshape(24,)

# %% [markdown]
# ### 2D Array

# %%
a2 = a1.reshape((4,6))
a2

# %%
a1.reshape(-1,6)

# %%
# reshape it back to 1D
a2.reshape(24,)

# %% [markdown]
# ### 3D Array

# %%
a3 = a1.reshape((2, 3, 4))
a3

# %%
# Slice only the first 2D Array of the 3D array
a3[0,:,:]

# %%
a3.reshape(24,)

# %%
a3.reshape(24)

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris

# %%
X = iris.drop(columns=['species'])
y = iris['species']
y.unique()

# %%
# Use a dendrogram to find the optimal number of clusters.
# %matplotlib inline
import pandas as pd
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward')) # 'Ward' minimizes the within-cluster variance.
plt.title('Dendrogram')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# # 2. Recap part two at 5pm

# %% [markdown]
# ### Correction of challenge face_recognition : What are your Principal Components?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### T-SNE for dim. reduction in 3D
# - Step 1: Explain T-SNE intuitively, using for instance [distill](https://distill.pub/2016/misread-tsne/) or [this blog](https://towardsdatascience.com/t-sne-clearly-explained-d84c537f53a)
#
#
# - Step 2: Illustrate it with https://projector.tensorflow.org/ loading for instance [this dataset of 100,000 wine bottle reviews](https://projector.tensorflow.org/?config=https://gist.githubusercontent.com/arthurchiquet/7a34ec908855cd6729d15a71ed25a812/raw/7f7468821b0a5d4e77f6fe7d29245ae159ddf388/Embeddings) that have been WordEmbedded in 100-dim vectors each, and projected into 3D space. Explain how T-SNE is better at separating our datainto cluster than PCA. Show how T-SNE is able to "find" wine country-of-origin automatically by coloring datapoints per country! Note that the country of origin is NOT known by the T-SNE algorithm beforehand! The wine reviews do not contain country of origin in their text!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Or, one can always generate its own TSV dataset and load it to projector.tensorflow, for instance as per below.
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine, load_diabetes, load_breast_cancer, fetch_covtype

# %%
diabetes = load_diabetes(as_frame=True)
cancer = load_breast_cancer(as_frame=True)
covtype = fetch_covtype()

# %%
cancer.data.to_csv('cancer-tsne.csv', index=False, header=False, sep='\t')

cancer.target.to_csv('cancer-tsne-target.csv', index=False, header=False, sep='\t')

wine.data.to_csv('wine-tsne.csv', index=False, header=False, sep='\t')

diabetes.data.to_csv('diabetes-tsne.csv', index=False, header=False, sep='\t')
