# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
import requests

url = "https://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data = requests.get(url).json()

# %%
apple_df = pd.DataFrame(api_data)

# %%
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   close                 65 non-null     float64
#  1   high                  65 non-null     float64
#  2   low                   65 non-null     float64
#  3   open                  65 non-null     float64
#  4   symbol                65 non-null     object
#  5   volume                65 non-null     int64
#  6   id                    65 non-null     object
#  7   key                   65 non-null     object
#  8   subkey                65 non-null     object
#  9   date                  65 non-null     object
#  10  updated               65 non-null     int64
#  11  changeOverTime        65 non-null     float64
#  12  marketChangeOverTime  65 non-null     float64
#  13  uOpen                 65 non-null     float64
#  14  uClose                65 non-null     float64
#  15  uHigh                 65 non-null     float64
#  16  uLow                  65 non-null     float64
#  17  uVolume               65 non-null     int64
#  18  fOpen                 65 non-null     float64
#  19  fClose                65 non-null     float64
#  20  fHigh                 65 non-null     float64
#  21  fLow                  65 non-null     float64
#  22  fVolume               65 non-null     int64
#  23  label                 65 non-null     object
#  24  change                65 non-null     float64
#  25  changePercent         65 non-null     float64
# dtypes: float64(16), int64(4), object(6)
# memory usage: 13.3+ KB

# %%
apple_df['date'] = pd.to_datetime(apple_df['date'])

# %%
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   close                 65 non-null     float64
#  1   high                  65 non-null     float64
#  2   low                   65 non-null     float64
#  3   open                  65 non-null     float64
#  4   symbol                65 non-null     object
#  5   volume                65 non-null     int64
#  6   id                    65 non-null     object
#  7   key                   65 non-null     object
#  8   subkey                65 non-null     object
#  9   date                  65 non-null     datetime64[ns]
#  10  updated               65 non-null     int64
#  11  changeOverTime        65 non-null     float64
#  12  marketChangeOverTime  65 non-null     float64
#  13  uOpen                 65 non-null     float64
#  14  uClose                65 non-null     float64
#  15  uHigh                 65 non-null     float64
#  16  uLow                  65 non-null     float64
#  17  uVolume               65 non-null     int64
#  18  fOpen                 65 non-null     float64
#  19  fClose                65 non-null     float64
#  20  fHigh                 65 non-null     float64
#  21  fLow                  65 non-null     float64
#  22  fVolume               65 non-null     int64
#  23  label                 65 non-null     object
#  24  change                65 non-null     float64
#  25  changePercent         65 non-null     float64
# dtypes: datetime64[ns](1), float64(16), int64(4), object(5)
# memory usage: 13.3+ KB

# %%
apple_df = apple_df.set_index(['date'])
apple_df
# Out:
#              close      high     low    open symbol     volume  \
# date
# 2021-07-12  144.50  146.3200  144.00  146.21   AAPL   76299719
# 2021-07-13  145.64  147.4600  143.63  144.03   AAPL  100827099
# 2021-07-14  149.15  149.5700  147.68  148.10   AAPL  127050785
# 2021-07-15  148.48  150.0000  147.09  149.24   AAPL  106820297
# 2021-07-16  146.39  149.7600  145.88  148.46   AAPL   93251426
# ...            ...       ...     ...     ...    ...        ...
# 2021-10-05  141.11  142.2400  139.36  139.49   AAPL   80861062
# 2021-10-06  142.00  142.1500  138.37  139.47   AAPL   83221119
# 2021-10-07  143.29  144.2150  142.72  143.06   AAPL   61732656
# 2021-10-08  142.90  144.1781  142.56  144.03   AAPL   58773155
# 2021-10-11  142.81  144.8100  141.81  142.27   AAPL   64452219
#
#                            id   key subkey        updated  ...    uLow  \
# date                                                       ...
# 2021-07-12  HISTORICAL_PRICES  AAPL         1628262978000  ...  144.00
# 2021-07-13  HISTORICAL_PRICES  AAPL         1628263183000  ...  143.63
# 2021-07-14  HISTORICAL_PRICES  AAPL         1628263006000  ...  147.68
# 2021-07-15  HISTORICAL_PRICES  AAPL         1628263089000  ...  147.09
# 2021-07-16  HISTORICAL_PRICES  AAPL         1628262975000  ...  145.88
# ...                       ...   ...    ...            ...  ...     ...
# 2021-10-05  HISTORICAL_PRICES  AAPL         1633484350000  ...  139.36
# 2021-10-06  HISTORICAL_PRICES  AAPL         1633570596000  ...  138.37
# 2021-10-07  HISTORICAL_PRICES  AAPL         1633656987000  ...  142.72
# 2021-10-08  HISTORICAL_PRICES  AAPL         1633742309000  ...  142.56
# 2021-10-11  HISTORICAL_PRICES  AAPL         1634000540000  ...  141.81
#
#               uVolume     fOpen    fClose     fHigh      fLow    fVolume  \
# date
# 2021-07-12   76299719  145.9913  144.2838  146.1011  143.7846   76299719
# 2021-07-13  100827099  143.8145  145.4221  147.2394  143.4151  100827099
# 2021-07-14  127050785  147.8784  148.9269  149.3462  147.4591  127050785
# 2021-07-15  106820297  149.0167  148.2579  149.7756  146.8700  106820297
# 2021-07-16   93251426  148.2379  146.1710  149.5360  145.6618   93251426
# ...               ...       ...       ...       ...       ...        ...
# 2021-10-05   80861062  139.4900  141.1100  142.2400  139.3600   80861062
# 2021-10-06   83221119  139.4700  142.0000  142.1500  138.3700   83221119
# 2021-10-07   61732656  143.0600  143.2900  144.2150  142.7200   61732656
# 2021-10-08   58773155  144.0300  142.9000  144.1781  142.5600   58773155
# 2021-10-11   64452219  142.2700  142.8100  144.8100  141.8100   64452219
#
#                  label  change  changePercent
# date
# 2021-07-12  Jul 12, 21    0.00         0.0000
# 2021-07-13  Jul 13, 21    1.14         0.0079
# 2021-07-14  Jul 14, 21    3.51         0.0241
# 2021-07-15  Jul 15, 21   -0.67        -0.0045
# 2021-07-16  Jul 16, 21   -2.09        -0.0141
# ...                ...     ...            ...
# 2021-10-05   Oct 5, 21    1.97         0.0142
# 2021-10-06   Oct 6, 21    0.89         0.0063
# 2021-10-07   Oct 7, 21    1.29         0.0091
# 2021-10-08   Oct 8, 21   -0.39        -0.0027
# 2021-10-11  Oct 11, 21   -0.09        -0.0006
#
# [65 rows x 25 columns]

# %%
apple_df['close'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
apple_df[['open','close','high','low']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
apple_df[['open','close','high','low']].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from nbresult import ChallengeResult

result = ChallengeResult('apple',
    index_name=apple_df.index.name,
    index_type=apple_df.index.dtype,
    columns=apple_df.columns
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /home/useradd/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/useradd/code/LucaVanTichelen/data-challenges/02-Data-Toolkit/02-Data-Sourcing/01-Stock-Market-API
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 3 items
#
# tests/test_apple.py::TestApple::test_apple_df_columns PASSED             [ 33%]
# tests/test_apple.py::TestApple::test_apple_df_index_is_timestamp PASSED  [ 66%]
# tests/test_apple.py::TestApple::test_apple_df_index_name_is_date PASSED  [100%]
#
# ============================== 3 passed in 0.32s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/apple.pickle
#
# git commit -m 'Completed apple step'
#
# git push origin master
